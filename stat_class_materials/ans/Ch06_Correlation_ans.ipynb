# %% [markdown]
# ### Task
# 1. Import everything.

# %%
import numpy as np
import scipy.stats as stat
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Task
# 1. Create normally distributed random numbers. Two of them, data_1 and data_2.
# 2. As long as they are normally distributed, mean and stdev are up to you. Feel free.
# 3. When you're done step 2, add data_1 to data_2.

# %%
np.random.seed(42)
data_1 = 20 * np.random.randn(1000) + 100
data_2 = data_1 + (10 * np.random.randn(1000) + 50)

# %% [markdown]
# ### Task
# 1. Find mean and stdev for both.

# %%
print('data_1: mean=%.3f stdev=%.3f' % (np.mean(data_1), np.std(data_1)))
print('data_2: mean=%.3f stdev=%.3f' % (np.mean(data_2), np.std(data_2)))
# Out:
# data_1: mean=100.387 stdev=19.575
# data_2: mean=151.095 stdev=21.605

# %% [markdown]
# ### Task
# 1. Plot them. x being data_1 adn y, data_2.

# %%
# plot
plt.scatter(data_1, data_2, s=5)
plt.show()

# %% [markdown]
# ### Task
# 1. Do they look correlated? Of course they do, data_1 got added to data_2.
# 2. Find the covariance first.
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.cov.html

# %%
print("covariance: ",np.cov(data_1,data_2))
# Out:
# covariance:  [[383.54554143 375.65364293]
#  [375.65364293 467.25326789]]

# %% [markdown]
# ### Task
# 1. Find the Pearson's correlation coefficient.
#
# https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.pearsonr.html

# %%
corr,_ = stat.pearsonr(data_1,data_2)
print("Pearson's corr. coeff. : %.4f"%corr)
# Out:
# Pearson's corr. coeff. : 0.8874

# %% [markdown]
# ### Task
# 1. Find the Spearman's correlation coefficient.
#
# https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.spearmanr.html

# %%
corr,_ = stat.spearmanr(data_1,data_2)
print("Speaman's corr. coeff. : %.4f"%corr)
# Out:
# Speaman's corr. coeff. : 0.8815
